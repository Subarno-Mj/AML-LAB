# %% [markdown]
# Bias Variance

# %%
print("Bias Variance...")
# Out:
# Bias Variance...

# %%
# %pip install numpy matplotlib scikit-learn pandas
# Out:
# Collecting numpy
#   Using cached numpy-2.5.3-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.11.2-cp314-cp314-win_amd64.whl.metadata (80 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.9.1-cp314-cp314-win_amd64.whl.metadata (9.3 kB)
# Collecting pandas
#   Using cached pandas-3.0.5-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.4.0-cp314-cp314-win_amd64.whl.metadata (3.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.65.0-cp314-cp314-win_amd64.whl.metadata (127 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.5.1-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in .\.venv\Lib\site-packages (from matplotlib) (26.3)
# Collecting pillow>=9 (from matplotlib)
#   Using cached pillow-12.3.0-cp314-cp314-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in .\.venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Using cached scipy-1.18.1-cp314-cp314-win_amd64.whl.metadata (61 kB)
# Collecting joblib>=1.4.0 (from scikit-learn)
#   Using cached joblib-1.6.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn)
#   Using cached narwhals-2.26.0-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting tzdata (from pandas)
#   Downloading tzdata-2026.4-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting cloudpickle>=3.0 (from joblib>=1.4.0->scikit-learn)
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached numpy-2.5.3-cp314-cp314-win_amd64.whl (12.7 MB)
# Downloading matplotlib-3.11.2-cp314-cp314-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.5 MB 9.0 MB/s eta 0:00:01
#    ------------ --------------------------- 2.9/9.5 MB 8.6 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/9.5 MB 8.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.1/9.5 MB 9.0 MB/s eta 0:00:01
#    ------------------------------------- -- 8.9/9.5 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 9.1 MB/s  0:00:01
# Downloading scikit_learn-1.9.1-cp314-cp314-win_amd64.whl (8.4 MB)
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    -------- ------------------------------- 1.8/8.4 MB 9.8 MB/s eta 0:00:01
#    ------------------ --------------------- 3.9/8.4 MB 9.5 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.4 MB 9.0 MB/s eta 0:00:01
#    -------------------------------- ------- 6.8/8.4 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.4/8.4 MB 8.2 MB/s  0:00:01
# Using cached pandas-3.0.5-cp314-cp314-win_amd64.whl (10.0 MB)
# Downloading contourpy-1.4.0-cp314-cp314-win_amd64.whl (240 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.65.0-cp314-cp314-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ------------------------- -------------- 1.6/2.5 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 7.8 MB/s  0:00:00
# Using cached joblib-1.6.0-py3-none-any.whl (306 kB)
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached kiwisolver-1.5.1-cp314-cp314-win_amd64.whl (72 kB)
# Using cached narwhals-2.26.0-py3-none-any.whl (474 kB)
# Using cached pillow-12.3.0-cp314-cp314-win_amd64.whl (7.2 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Using cached scipy-1.18.1-cp314-cp314-win_amd64.whl (37.4 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2026.4-py2.py3-none-any.whl (347 kB)
# Installing collected packages: tzdata, threadpoolctl, pyparsing, pillow, numpy, narwhals, kiwisolver, fonttools, cycler, cloudpickle, scipy, pandas, joblib, contourpy, scikit-learn, matplotlib
#
#    ----- ----------------------------------  2/16 [pyparsing]
#    ------- --------------------------------  3/16 [pillow]
#    ------- --------------------------------  3/16 [pillow]
#    ------- --------------------------------  3/16 [pillow]
#    ------- --------------------------------  3/16 [pillow]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ---------- -----------------------------  4/16 [numpy]
#    ------------ ---------------------------  5/16 [narwhals]
#    ------------ ---------------------------  5/16 [narwhals]
#    ------------ ---------------------------  5/16 [narwhals]
#    ------------ ---------------------------  5/16 [narwhals]
#    ------------ ---------------------------  5/16 [narwhals]
#    ------------ ---------------------------  5/16 [narwhals]
#    ----------------- ----------------------  7/16 [fonttools]
#    ----------------- ----------------------  7/16 [fonttools]
#    ----------------- ----------------------  7/16 [fonttools]
#    ----------------- ----------------------  7/16 [fonttools]
#    ----------------- ----------------------  7/16 [fonttools]
#    ----------------- ----------------------  7/16 [fonttools]
#    ----------------- ----------------------  7/16 [fonttools]
#    ----------------- ----------------------  7/16 [fonttools]
#    ----------------- ----------------------  7/16 [fonttools]
#    ----------------- ----------------------  7/16 [fonttools]
#    ----------------- ----------------------  7/16 [fonttools]
#    ----------------- ----------------------  7/16 [fonttools]
#    ----------------- ----------------------  7/16 [fonttools]
#    ----------------- ----------------------  7/16 [fonttools]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    ------------------------- -------------- 10/16 [scipy]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    --------------------------- ------------ 11/16 [pandas]
#    ------------------------------ --------- 12/16 [joblib]
#    ------------------------------ --------- 12/16 [joblib]
#    -------------------------------- ------- 13/16 [contourpy]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ----------------------------------- ---- 14/16 [scikit-learn]
#    ------------------------------------- -- 15/16 [matplotlib]
#    ------------------------------------- -- 15/16 [matplotlib]
#    ------------------------------------- -- 15/16 [matplotlib]
#    ------------------------------------- -- 15/16 [matplotlib]
#    ------------------------------------- -- 15/16 [matplotlib]
#    ------------------------------------- -- 15/16 [matplotlib]
#    ------------------------------------- -- 15/16 [matplotlib]
#    ------------------------------------- -- 15/16 [matplotlib]
#    ------------------------------------- -- 15/16 [matplotlib]
#    ------------------------------------- -- 15/16 [matplotlib]
#    ------------------------------------- -- 15/16 [matplotlib]
#    ------------------------------------- -- 15/16 [matplotlib]
#    ------------------------------------- -- 15/16 [matplotlib]
#    ------------------------------------- -- 15/16 [matplotlib]
#    ------------------------------------- -- 15/16 [matplotlib]
#    ------------------------------------- -- 15/16 [matplotlib]
#    ------------------------------------- -- 15/16 [matplotlib]
#    ---------------------------------------- 16/16 [matplotlib]
#
# Successfully installed cloudpickle-3.1.2 contourpy-1.4.0 cycler-0.12.1 fonttools-4.65.0 joblib-1.6.0 kiwisolver-1.5.1 matplotlib-3.11.2 narwhals-2.26.0 numpy-2.5.3 pandas-3.0.5 pillow-12.3.0 pyparsing-3.3.2 scikit-learn-1.9.1 scipy-1.18.1 threadpoolctl-3.6.0 tzdata-2026.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error

# %%
# Generate reproducible non-linear data
np.random.seed(42)

X = np.linspace(0, 10, 40).reshape(-1, 1)

y = 2 + 0.5 * X[:, 0]**2 + np.random.normal(0, 5, 40)

# Divide the data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

degrees = [1, 2, 10]

# Train and evaluate each polynomial model
for degree in degrees:
    model = make_pipeline(
        PolynomialFeatures(degree=degree, include_bias=False),
        LinearRegression()
    )

    model.fit(X_train, y_train)

    train_prediction = model.predict(X_train)
    test_prediction = model.predict(X_test)

    train_mse = mean_squared_error(y_train, train_prediction)
    test_mse = mean_squared_error(y_test, test_prediction)

    print(f"Polynomial degree: {degree}")
    print(f"Training MSE: {train_mse:.2f}")
    print(f"Testing MSE: {test_mse:.2f}")
    print()
# Out:
# Polynomial degree: 1
# Training MSE: 42.90
# Testing MSE: 42.99
#
# Polynomial degree: 2
# Training MSE: 20.44
# Testing MSE: 19.79
#
# Polynomial degree: 10
# Training MSE: 18.26
# Testing MSE: 38.42

# %% [markdown]
# Assignment

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error

# Generate reproducible non-linear data
np.random.seed(42)

X = np.linspace(0, 10, 1000).reshape(-1, 1)

y = 2 + 0.5 * X[:, 0]**2 + np.random.normal(0, 5, 1000)

degrees = [1, 2, 3, 4, 5, 10]
test_sizes = [0.2, 0.25, 0.3]

results = []

for test_size in test_sizes:

    X_train, X_test, y_train, y_test = train_test_split(
        X, y,
        test_size=test_size,
        random_state=42
    )

    print(f"\nTest Size: {test_size}")

    for degree in degrees:

        model = make_pipeline(
            PolynomialFeatures(
                degree=degree,
                include_bias=False
            ),
            LinearRegression()
        )

        model.fit(X_train, y_train)

        train_prediction = model.predict(X_train)
        test_prediction = model.predict(X_test)

        train_mse = mean_squared_error(
            y_train,
            train_prediction
        )

        test_mse = mean_squared_error(
            y_test,
            test_prediction
        )

        results.append({
            "test_size": test_size,
            "degree": degree,
            "train_mse": train_mse,
            "test_mse": test_mse
        })

        print(
            f"Degree {degree}: "
            f"Train MSE = {train_mse:.2f}, "
            f"Test MSE = {test_mse:.2f}"
        )


# Find best model
best_model = min(
    results,
    key=lambda x: x["test_mse"]
)

print("\nBest Model is --")
print(f"Degree: {best_model['degree']}")
print(f"Test Size: {best_model['test_size']}")
print(f"Train MSE: {best_model['train_mse']:.2f}")
print(f"Test MSE: {best_model['test_mse']:.2f}")
# Out:
# Test Size: 0.2
# Degree 1: Train MSE = 38.77, Test MSE = 36.17
# Degree 2: Train MSE = 23.95, Test MSE = 23.80
# Degree 3: Train MSE = 23.91, Test MSE = 23.87
# Degree 4: Train MSE = 23.84, Test MSE = 23.58
# Degree 5: Train MSE = 23.82, Test MSE = 23.44
# Degree 10: Train MSE = 26.13, Test MSE = 26.32
#
# Test Size: 0.25
# Degree 1: Train MSE = 37.91, Test MSE = 39.29
# Degree 2: Train MSE = 23.75, Test MSE = 24.52
# Degree 3: Train MSE = 23.68, Test MSE = 24.70
# Degree 4: Train MSE = 23.63, Test MSE = 24.42
# Degree 5: Train MSE = 23.63, Test MSE = 24.36
# Degree 10: Train MSE = 26.07, Test MSE = 26.67
#
# Test Size: 0.3
# Degree 1: Train MSE = 37.99, Test MSE = 38.88
# Degree 2: Train MSE = 23.77, Test MSE = 24.40
# Degree 3: Train MSE = 23.64, Test MSE = 24.83
# Degree 4: Train MSE = 23.58, Test MSE = 24.59
# Degree 5: Train MSE = 23.58, Test MSE = 24.60
# Degree 10: Train MSE = 26.24, Test MSE = 26.35
#
# Best Model is --
# Degree: 5
# Test Size: 0.2
# Train MSE: 23.82
# Test MSE: 23.44
